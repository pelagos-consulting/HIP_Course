# %% [markdown]
# # Exercise - Hadamard (elementwise) matrix multiplication
#
# In this exercise we are going to solidify our understanding of HIP applications using Hadamard matrix multiplication. Hadamard multiplication is elementwise multiplication. The values in matrices **D** and **E** at coordinates (i0,i1) are multiplied together to set the value at coordinates (i0,i1) in matrix **F**.
#
# <figure style="margin-left:auto; margin-right:auto; width:80%;">
#     <img style="vertical-align:middle" src="../../images/elementwise_multiplication.svg">
#     <figcaption style= "text-align:lower; margin:1em; float:bottom; vertical-align:bottom;">Elementwise multiplication of matrices D and E to get F.</figcaption>
# </figure>
#
# The source code is located in [elementwise_challenge.cpp](elementwise_challenge.cpp) and is similar to the matrix multiplication example <a href="../../L3_Matrix_Multiplication/mat_mult.cpp">mat_mult.cpp</a> in almost every aspect. The steps are:
#
# 1. Device discovery and selection
# 1. Matrices **D_h** and **E_h** allocated on the host and filled with random numbers.
# 1. Matrices **D_d** and **E_d** allocated on the compute device
# 1. Matrices **D_h** and **E_h** uploaded to device allocations **D_d** and **E_d**
# 1. The kernel **mat_elementwise** is run on the device to compute **F_d** from **D_d** and **E_d**.
# 1. **F_d** is copied to **F_h** and compared with the solution **F_answer_h** from sequential CPU code.
# 1. Memory and device cleanup

# %% [markdown]
# ## Compile and run the answer
#
# We compile and run the solution [elementwise_challenge_answer.cpp](elementwise_challenge_answer.cpp) as shown below. We are using a really small matrix (8,4) so that the exercise may be done from the command line.

# %%
import os
os.environ['PATH'] = f"{os.environ['PATH']}:../../install/bin"

# At a Bash terminal you need to do this instead
# source ../env

# %%
# !build elementwise_challenge_answer.exe; elementwise_challenge_answer.exe
# Out:
# [ 50%] Built target hip_helper
# [100%] Built target elementwise_challenge_answer.exe
# Install the project...
# -- Install configuration: "RELEASE"
# Device id: 0
# 	name:                                    NVIDIA GeForce RTX 3060 Laptop GPU
# 	global memory size:                      6219 MB
# 	available registers per block:           65536
# 	max threads per SM or CU:                1536
# 	maximum shared memory size per block:    49 KB
# 	maximum shared memory size per SM or CU: 8854831181210171 KB
# 	maximum pitch size for memory copies:    2147 MB
# 	max block size:                          (1024,1024,64)
# 	max threads in a block:                  1024
# 	max Grid size:                           (2147483647,65535,65535)
# The output array F_h (as computed with HIP) is
# ----
# |  4.50e-01  1.70e-01  2.77e-01  2.21e-02 |
# |  2.46e-02  3.48e-02  4.41e-02  2.05e-01 |
# |  7.57e-01  4.06e-03  3.90e-01  2.74e-01 |
# |  3.16e-01  3.38e-05  9.45e-02  9.03e-01 |
# |  1.60e-02  6.24e-03  9.69e-02  4.00e-01 |
# |  4.89e-01  4.12e-01  8.46e-01  8.93e-02 |
# |  3.23e-01  3.19e-02  2.84e-01  4.18e-01 |
# |  2.02e-02  3.38e-01  2.30e-01  1.49e-01 |
# ----
# The CPU solution (F_answer_h) is
# ----
# |  4.50e-01  1.70e-01  2.77e-01  2.21e-02 |
# |  2.46e-02  3.48e-02  4.41e-02  2.05e-01 |
# |  7.57e-01  4.06e-03  3.90e-01  2.74e-01 |
# |  3.16e-01  3.38e-05  9.45e-02  9.03e-01 |
# |  1.60e-02  6.24e-03  9.69e-02  4.00e-01 |
# |  4.89e-01  4.12e-01  8.46e-01  8.93e-02 |
# |  3.23e-01  3.19e-02  2.84e-01  4.18e-01 |
# |  2.02e-02  3.38e-01  2.30e-01  1.49e-01 |
# ----
# The residual (F_answer_h-F_h) is
# ----
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# ----

# %% [markdown]
# This is what we expect to see. The residual (last matrix shown) is the result of subtracting the HIP output (**F_h**) from the CPU output and is 0 everywhere.

# %% [markdown]
# ## Compile and run the exercise
#
# The exercise [elementwise_challenge.cpp](elementwise_challenge.cpp) is missing a number of crucial pieces of software. If we compile and run we see a non-zero residual. Copy this command to the command line (without the !) and run it as follows:

# %%
# !build elementwise_challenge.exe; elementwise_challenge.exe
# Out:
# [ 50%] Built target hip_helper
# [100%] Built target elementwise_challenge.exe
# Install the project...
# -- Install configuration: "RELEASE"
# Device id: 0
# 	name:                                    NVIDIA GeForce RTX 3060 Laptop GPU
# 	global memory size:                      6219 MB
# 	available registers per block:           65536
# 	max threads per SM or CU:                1536
# 	maximum shared memory size per block:    49 KB
# 	maximum shared memory size per SM or CU: 0 KB
# 	maximum pitch size for memory copies:    2147 MB
# 	max block size:                          (1024,1024,64)
# 	max threads in a block:                  1024
# 	max Grid size:                           (2147483647,65535,65535)
# The output array F_h (as computed with HIP) is
# ----
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# ----
# The CPU solution (F_answer_h) is
# ----
# |  4.50e-01  1.70e-01  2.77e-01  2.21e-02 |
# |  2.46e-02  3.48e-02  4.41e-02  2.05e-01 |
# |  7.57e-01  4.06e-03  3.90e-01  2.74e-01 |
# |  3.16e-01  3.38e-05  9.45e-02  9.03e-01 |
# |  1.60e-02  6.24e-03  9.69e-02  4.00e-01 |
# |  4.89e-01  4.12e-01  8.46e-01  8.93e-02 |
# |  3.23e-01  3.19e-02  2.84e-01  4.18e-01 |
# |  2.02e-02  3.38e-01  2.30e-01  1.49e-01 |
# ----
# The residual (F_answer_h-F_h) is
# ----
# |  4.50e-01  1.70e-01  2.77e-01  2.21e-02 |
# |  2.46e-02  3.48e-02  4.41e-02  2.05e-01 |
# |  7.57e-01  4.06e-03  3.90e-01  2.74e-01 |
# |  3.16e-01  3.38e-05  9.45e-02  9.03e-01 |
# |  1.60e-02  6.24e-03  9.69e-02  4.00e-01 |
# |  4.89e-01  4.12e-01  8.46e-01  8.93e-02 |
# |  3.23e-01  3.19e-02  2.84e-01  4.18e-01 |
# |  2.02e-02  3.38e-01  2.30e-01  1.49e-01 |
# ----

# %% [markdown]
# As you can see the residual is non-zero, which means that the output is incorrect. The challenge is to edit [elementwise_challenge.cpp](elementwise_challenge.cpp) so that it produces the same result as the solution [elementwise_challenge_answer.cpp](elementwise_challenge_answer.cpp).

# %% [markdown]
# ## Choose your own coding adventure!
#
# As it stands the exercise [elementwise_challenge.cpp](elementwise_challenge.cpp) is missing a number of **crucial** steps. Each step is clearly marked out in the code using quadruple slash `////` comments.
#
# 1. Kernel code to perform the actual elementwise multiplication.
#     * Make sure you have a guard statement in place so that you don't overun the bounds of F.
#     * Use multi-dimensional indexing as shown in the Survival C++ Lesson to index into arrays.
#     * If you get stuck you can just uncomment the include statement, similar to the following:
#     <br><br>
#     ```C++
#     // Uncomment for the shortcut answer
#     // #include "step1_kernel.cpp"
#     ```
#     <br>
# 1. Initialise HIP and set the compute device.
#     * Call **hipInit** to initialise HIP.
#     * Get the device count with **hipGetDeviceCount** and perform sanity checking on the device index.
#     * Call **hipSetDevice** to set the compute device.
#     * Always check the return code of API calls with **H_ERRCHK**.
# 1. Allocate memory for arrays **D_d**, **E_d** and **F_d** on the compute device.
#     * Call **hipMalloc** to allocate memory.
# 1. Upload memory from arrays **D_h** and **E_h** on the host to **E_d** and **F_d** on the device.
#     * Call **hipMemcpy** to copy memory from host to device.
# 1. Launch the kernel and wait for it to complete
#     * Use the **hipLaunchKernelGGL** macro.
#     * Use **hipDeviceSynchronize** to wait for the kernel.
# 1. Copy the solution **F_d** on the compute device back to **F_h** on the host.
#     * Call **hipMemcpy** to copy memory from device to host.
# 1. Free memory for **D_d**, **E_d**, and **F_d** on the compute device.
#     * Call **hipFree** to free up device memory.
# 1. Reset the compute device and destroy context
#     * Call **hipDeviceSynchronize** to wait for devices.
#     * Call **hipDeviceReset** to release the primary context on each device.
#
# As a HIP developer your job is to provide source code to fill in the missing steps, using either the template code in <a href="../../L3_Matrix_Multiplication/mat_mult.cpp">mat_mult.cpp</a> or by peeking at the solution in [elementwise_challenge_answer.cpp](elementwise_challenge_answer.cpp). You can make these tasks as easy or as challenging as you wish. Each of the steps has a **shortcut solution** that you can access by uncommenting the code snippet that has the answer. For example see these lines for step 2 in [elementwise_challenge.cpp](elementwise_challenge.cpp).
#
# ```C++
#     //// Step 2. Discover resources ////
#     //// Call hipInit to intialise HIP ////
#     //// Call hipGetDeviceCount to fill num_devices ////
#     //// Make sure dev_index is sane
#     //// Call hipSetDevice to set the compute device ///
#
#     // Uncomment for the shortcut answer
#     // #include "step2_resources.cpp"
#
#     //// End code: ////
# ```
#
# If you get stuck you can just uncomment the **#include** statement to bring in the solution for that step and move on to another, for example uncommenting this line brings in the solution to discover resources:
#
#
# ```C++
#     //// Step 2. Discover resources ////
#     //// Call hipInit to intialise HIP ////
#     //// Call hipGetDeviceCount to fill num_devices ////
#     //// Make sure dev_index is sane
#     //// Call hipSetDevice to set the compute device ///
#
#     // Uncomment for the shortcut answer
#     #include "step2_resources.cpp"
#
#     //// End code: ////
# ```
#
# The goal is to become familiar with looking up and implementing **HIP** API calls as well as familiarising yourself with best practices. For your exercise you can choose to focus on as little as a **single task** or try to implement **all the tasks** yourself. It is up to you and how much you can accomplish within the time allotted. Some steps may depend on others, so if you skip a step just make sure you uncomment the include for the shortcut. Each time you make changes to the code you can run the following to test it out.

# %%
# !build elementwise_challenge.exe; elementwise_challenge.exe
# Out:
# [ 50%] Built target hip_helper
# Consolidate compiler generated dependencies of target elementwise_challenge.exe
# nvcc warning : incompatible redefinition for option 'optimize', the last value of this option was used
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h(506): warning #1056-D: returning pointer to local variable
#       return &a;
#              ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h(506): warning #1056-D: returning pointer to local variable
#       return &a;
#              ^
#
# Remark: The warnings can be suppressed with "-diag-suppress <warning-number>"
#
# /home/toby/Pelagos/Projects/HIP_Course/course_material/Exercises/E3_Elementwise_Challenge/elementwise_challenge.cpp(31): warning #177-D: variable "i0" was declared but never referenced
#       size_t i0 = blockIdx.y * blockDim.y + threadIdx.y;
#              ^
#
# /home/toby/Pelagos/Projects/HIP_Course/course_material/Exercises/E3_Elementwise_Challenge/elementwise_challenge.cpp(32): warning #177-D: variable "i1" was declared but never referenced
#       size_t i1 = blockIdx.x * blockDim.x + threadIdx.x;
#              ^
#
# /home/toby/Pelagos/Projects/HIP_Course/course_material/Exercises/E3_Elementwise_Challenge/elementwise_challenge.cpp(49): warning #177-D: variable "num_devices" was declared but never referenced
#       int num_devices=0;
#           ^
#
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘CUDA_RESOURCE_DESC* hipResourceDesTocudaResourceDes(const HIP_RESOURCE_DESC*)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:506:8: warning: address of local variable ‘a’ returned [-Wreturn-local-addr]
#   506 |     return &a;
#       |        ^~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:480:20: note: declared here
#   480 |     CUDA_RESOURCE_DESC a;
#       |                    ^
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipMemcpyToArray(hipArray_t, size_t, size_t, const void*, size_t, hipMemcpyKind)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:2070:48: warning: ‘cudaError_t cudaMemcpyToArray(cudaArray_t, size_t, size_t, const void*, size_t, cudaMemcpyKind)’ is deprecated [-Wdeprecated-declarations]
#  2070 |     return hipCUDAErrorTohipError(
#       |                               ~~~~             ^
# /usr/local/cuda-12.4/include/cuda_runtime_api.h:8181:46: note: declared here
#  8181 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaMemcpyToArray(cudaArray_t dst, size_t wOffset, size_t hOffset, const void *src, size_t count, enum cudaMemcpyKind kind);
#       |                                              ^~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipMemcpyFromArray(void*, hipArray_const_t, size_t, size_t, size_t, hipMemcpyKind)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:2077:50: warning: ‘cudaError_t cudaMemcpyFromArray(void*, cudaArray_const_t, size_t, size_t, size_t, cudaMemcpyKind)’ is deprecated [-Wdeprecated-declarations]
#  2077 |     return hipCUDAErrorTohipError(cudaMemcpyFromArray(dst, srcArray, wOffset, hOffset, count,
#       |                               ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda_runtime_api.h:8223:46: note: declared here
#  8223 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaMemcpyFromArray(void *dst, cudaArray_const_t src, size_t wOffset, size_t hOffset, size_t count, enum cudaMemcpyKind kind);
#       |                                              ^~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipFuncSetSharedMemConfig(const void*, hipSharedMemConfig)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:2108:57: warning: ‘cudaError_t cudaFuncSetSharedMemConfig(const void*, cudaSharedMemConfig)’ is deprecated [-Wdeprecated-declarations]
#  2108 |     return hipCUDAErrorTohipError(cudaFuncSetSharedMemConfig(func, config));
#       |                               ~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda_runtime_api.h:4971:46: note: declared here
#  4971 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaFuncSetSharedMemConfig(const void *func, enum cudaSharedMemConfig config);
#       |                                              ^~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipCtxSetSharedMemConfig(hipSharedMemConfig)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:2981:53: warning: ‘CUresult cuCtxSetSharedMemConfig(CUsharedconfig)’ is deprecated [-Wdeprecated-declarations]
#  2981 |     return hipCUResultTohipError(cuCtxSetSharedMemConfig((CUsharedconfig)config));
#       |                              ~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:6855:36: note: declared here
#  6855 | __CUDA_DEPRECATED CUresult CUDAAPI cuCtxSetSharedMemConfig(CUsharedconfig config);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipCtxGetSharedMemConfig(hipSharedMemConfig*)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:2985:53: warning: ‘CUresult cuCtxGetSharedMemConfig(CUsharedconfig*)’ is deprecated [-Wdeprecated-declarations]
#  2985 |     return hipCUResultTohipError(cuCtxGetSharedMemConfig((CUsharedconfig*)pConfig));
#       |                              ~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:6800:36: note: declared here
#  6800 | __CUDA_DEPRECATED CUresult CUDAAPI cuCtxGetSharedMemConfig(CUsharedconfig *pConfig);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipCtxDetach(hipCtx_t)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:2997:41: warning: ‘CUresult cuCtxDetach(CUcontext)’ is deprecated [-Wdeprecated-declarations]
#  2997 |     return hipCUResultTohipError(cuCtxDetach(ctx));
#       |                              ~~~~~~~~~~~^~~~~
# /usr/local/cuda-12.4/include/cuda.h:6755:36: note: declared here
#  6755 | __CUDA_DEPRECATED CUresult CUDAAPI cuCtxDetach(CUcontext ctx);
#       |                                    ^~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipDeviceComputeCapability(int*, int*, hipDevice_t)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3005:55: warning: ‘CUresult cuDeviceComputeCapability(int*, int*, CUdevice)’ is deprecated [-Wdeprecated-declarations]
#  3005 |     return hipCUResultTohipError(cuDeviceComputeCapability(major, minor, device));
#       |                              ~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:5440:36: note: declared here
#  5440 | __CUDA_DEPRECATED CUresult CUDAAPI cuDeviceComputeCapability(int *major, int *minor, CUdevice dev);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipDeviceGetSharedMemConfig(hipSharedMemConfig*)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3038:59: warning: ‘cudaError_t cudaDeviceGetSharedMemConfig(cudaSharedMemConfig*)’ is deprecated [-Wdeprecated-declarations]
#  3038 |     return hipCUDAErrorTohipError(cudaDeviceGetSharedMemConfig(config));
#       |                               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~
# /usr/local/cuda-12.4/include/cuda_runtime_api.h:1043:46: note: declared here
#  1043 | extern __CUDA_DEPRECATED __host__ __cudart_builtin__ cudaError_t CUDARTAPI cudaDeviceGetSharedMemConfig(enum cudaSharedMemConfig *pConfig);
#       |                                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipDeviceSetSharedMemConfig(hipSharedMemConfig)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3042:59: warning: ‘cudaError_t cudaDeviceSetSharedMemConfig(cudaSharedMemConfig)’ is deprecated [-Wdeprecated-declarations]
#  3042 |     return hipCUDAErrorTohipError(cudaDeviceSetSharedMemConfig(config));
#       |                               ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~
# /usr/local/cuda-12.4/include/cuda_runtime_api.h:1089:46: note: declared here
#  1089 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaDeviceSetSharedMemConfig(enum cudaSharedMemConfig config);
#       |                                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipModuleGetTexRef(CUtexref_st**, hipModule_t, const char*)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3071:47: warning: ‘CUresult cuModuleGetTexRef(CUtexref_st**, CUmodule, const char*)’ is deprecated [-Wdeprecated-declarations]
#  3071 |     return hipCUResultTohipError(cuModuleGetTexRef(pTexRef, hmod, name));
#       |                              ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:7407:36: note: declared here
#  7407 | __CUDA_DEPRECATED CUresult CUDAAPI cuModuleGetTexRef(CUtexref *pTexRef, CUmodule hmod, const char *name);
#       |                                    ^~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipLaunchCooperativeKernelMultiDevice(hipLaunchParams*, int, unsigned int)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3219:69: warning: ‘cudaError_t cudaLaunchCooperativeKernelMultiDevice(cudaLaunchParams*, unsigned int, unsigned int)’ is deprecated [-Wdeprecated-declarations]
#  3219 | rn hipCUDAErrorTohipError(cudaLaunchCooperativeKernelMultiDevice(launchParamsList, numDevices, flags));
#       |                       ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# /usr/local/cuda-12.4/include/cuda_runtime_api.h:4622:46: note: declared here
#  4622 | extern __CUDA_DEPRECATED __host__ cudaError_t CUDARTAPI cudaLaunchCooperativeKernelMultiDevice(struct cudaLaunchParams *launchParamsList, unsigned int numDevices, unsigned int flags  __dv(0));
#       |                                              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipModuleLaunchCooperativeKernelMultiDevice(hipFunctionLaunchParams*, unsigned int, unsigned int)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3226:66: warning: ‘CUresult cuLaunchCooperativeKernelMultiDevice(CUDA_LAUNCH_PARAMS*, unsigned int, unsigned int)’ is deprecated [-Wdeprecated-declarations]
#  3226 | eturn hipCUResultTohipError(cuLaunchCooperativeKernelMultiDevice(launchParamsList,
#       |                         ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~
#
# /usr/local/cuda-12.4/include/cuda.h:17082:36: note: declared here
# 17082 | __CUDA_DEPRECATED CUresult CUDAAPI cuLaunchCooperativeKernelMultiDevice(CUDA_LAUNCH_PARAMS *launchParamsList, unsigned int numDevices, unsigned int flags);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipTexRefSetAddressMode(CUtexref, int, CUaddress_mode)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3515:52: warning: ‘CUresult cuTexRefSetAddressMode(CUtexref, int, CUaddress_mode)’ is deprecated [-Wdeprecated-declarations]
#  3515 |     return hipCUResultTohipError(cuTexRefSetAddressMode(hTexRef,dim,am));
#       |                              ~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:21313:36: note: declared here
# 21313 | __CUDA_DEPRECATED CUresult CUDAAPI cuTexRefSetAddressMode(CUtexref hTexRef, int dim, CUaddress_mode am);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipTexRefSetFilterMode(CUtexref, CUfilter_mode)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3519:51: warning: ‘CUresult cuTexRefSetFilterMode(CUtexref, CUfilter_mode)’ is deprecated [-Wdeprecated-declarations]
#  3519 |     return hipCUResultTohipError(cuTexRefSetFilterMode(hTexRef,fm));
#       |                              ~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:21349:36: note: declared here
# 21349 | __CUDA_DEPRECATED CUresult CUDAAPI cuTexRefSetFilterMode(CUtexref hTexRef, CUfilter_mode fm);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipTexRefSetAddress(size_t*, CUtexref, hipDeviceptr_t, size_t)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3523:51: warning: ‘CUresult cuTexRefSetAddress_v2(size_t*, CUtexref, CUdeviceptr, size_t)’ is deprecated [-Wdeprecated-declarations]
#  3523 |     return hipCUResultTohipError(cuTexRefSetAddress(ByteOffset,hTexRef,dptr,bytes));
#       |                              ~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:21183:36: note: declared here
# 21183 | __CUDA_DEPRECATED CUresult CUDAAPI cuTexRefSetAddress(size_t *ByteOffset, CUtexref hTexRef, CUdeviceptr dptr, size_t bytes);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipTexRefSetAddress2D(CUtexref, const CUDA_ARRAY_DESCRIPTOR*, hipDeviceptr_t, size_t)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3527:53: warning: ‘CUresult cuTexRefSetAddress2D_v3(CUtexref, const CUDA_ARRAY_DESCRIPTOR*, CUdeviceptr, size_t)’ is deprecated [-Wdeprecated-declarations]
#  3527 |     return hipCUResultTohipError(cuTexRefSetAddress2D(hTexRef,desc,dptr,Pitch));
#       |                              ~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:21238:36: note: declared here
# 21238 | __CUDA_DEPRECATED CUresult CUDAAPI cuTexRefSetAddress2D(CUtexref hTexRef, const CUDA_ARRAY_DESCRIPTOR *desc, CUdeviceptr dptr, size_t Pitch);
#       |                                    ^~~~~~~~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipTexRefSetFormat(CUtexref, CUarray_format, int)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3531:47: warning: ‘CUresult cuTexRefSetFormat(CUtexref, CUarray_format, int)’ is deprecated [-Wdeprecated-declarations]
#  3531 |     return hipCUResultTohipError(cuTexRefSetFormat(hTexRef,fmt,NumPackedComponents));
#       |                              ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:21270:36: note: declared here
# 21270 | __CUDA_DEPRECATED CUresult CUDAAPI cuTexRefSetFormat(CUtexref hTexRef, CUarray_format fmt, int NumPackedComponents);
#       |                                    ^~~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipTexRefSetFlags(CUtexref, unsigned int)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3535:46: warning: ‘CUresult cuTexRefSetFlags(CUtexref, unsigned int)’ is deprecated [-Wdeprecated-declarations]
#  3535 |     return hipCUResultTohipError(cuTexRefSetFlags(hTexRef,Flags));
#       |                              ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:21549:36: note: declared here
# 21549 | __CUDA_DEPRECATED CUresult CUDAAPI cuTexRefSetFlags(CUtexref hTexRef, unsigned int Flags);
#       |                                    ^~~~~~~~~~~~~~~~
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h: In function ‘hipError_t hipTexRefSetArray(CUtexref, hipArray_t, unsigned int)’:
# /opt/rocm-6.0.2/include/hip/nvidia_detail/nvidia_hip_runtime_api.h:3539:46: warning: ‘CUresult cuTexRefSetArray(CUtexref, CUarray, unsigned int)’ is deprecated [-Wdeprecated-declarations]
#  3539 |     return hipCUResultTohipError(cuTexRefSetArray(hTexRef,(CUarray)hArray,Flags));
#       |                              ~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# /usr/local/cuda-12.4/include/cuda.h:21107:36: note: declared here
# 21107 | __CUDA_DEPRECATED CUresult CUDAAPI cuTexRefSetArray(CUtexref hTexRef, CUarray hArray, unsigned int Flags);
#       |                                    ^~~~~~~~~~~~~~~~
# [100%] Built target elementwise_challenge.exe
# Install the project...
# -- Install configuration: "RELEASE"
# -- Set runtime path of "/home/toby/Pelagos/Projects/HIP_Course/course_material/install/bin/elementwise_challenge.exe" to "/home/toby/Pelagos/Projects/HIP_Course/course_material/install/lib"
# Device id: 0
# 	name:                                    NVIDIA GeForce RTX 3060 Laptop GPU
# 	global memory size:                      6219 MB
# 	available registers per block:           65536
# 	max threads per SM or CU:                1536
# 	maximum shared memory size per block:    49 KB
# 	maximum shared memory size per SM or CU: 0 KB
# 	maximum pitch size for memory copies:    2147 MB
# 	max block size:                          (1024,1024,64)
# 	max threads in a block:                  1024
# 	max Grid size:                           (2147483647,65535,65535)
# The output array F_h (as computed with HIP) is
# ----
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# |  0.00e+00  0.00e+00  0.00e+00  0.00e+00 |
# ----
# The CPU solution (F_answer_h) is
# ----
# |  4.50e-01  1.70e-01  2.77e-01  2.21e-02 |
# |  2.46e-02  3.48e-02  4.41e-02  2.05e-01 |
# |  7.57e-01  4.06e-03  3.90e-01  2.74e-01 |
# |  3.16e-01  3.38e-05  9.45e-02  9.03e-01 |
# |  1.60e-02  6.24e-03  9.69e-02  4.00e-01 |
# |  4.89e-01  4.12e-01  8.46e-01  8.93e-02 |
# |  3.23e-01  3.19e-02  2.84e-01  4.18e-01 |
# |  2.02e-02  3.38e-01  2.30e-01  1.49e-01 |
# ----
# The residual (F_answer_h-F_h) is
# ----
# |  4.50e-01  1.70e-01  2.77e-01  2.21e-02 |
# |  2.46e-02  3.48e-02  4.41e-02  2.05e-01 |
# |  7.57e-01  4.06e-03  3.90e-01  2.74e-01 |
# |  3.16e-01  3.38e-05  9.45e-02  9.03e-01 |
# |  1.60e-02  6.24e-03  9.69e-02  4.00e-01 |
# |  4.89e-01  4.12e-01  8.46e-01  8.93e-02 |
# |  3.23e-01  3.19e-02  2.84e-01  4.18e-01 |
# |  2.02e-02  3.38e-01  2.30e-01  1.49e-01 |
# ----

# %% [markdown]
# Have fun!

# %% [markdown]
# <address>
# Written by Dr. Toby Potter of <a href="https://www.pelagos-consulting.com">Pelagos Consulting and Education</a> for the Pawsey Supercomputing Centre.
# </address>
